# %%
import os
from serpapi import GoogleSearch
import regex as re

# %%
GOOGLE_SEARCH_API_KEY = os.environ["GOOGLE_SEARCH_API_KEY"]

# %%
title = "SummEval: Re-evaluating Summarization Evaluation"
params = {
    "engine": "google_scholar",
    "q": title,
    "api_key": GOOGLE_SEARCH_API_KEY
}

search = GoogleSearch(params)
results = search.get_dict()

# %%
results
# Out:
# {'search_metadata': {'id': '658c2d7d17f923a648d87cee',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/6daa55cb6296e7ee/658c2d7d17f923a648d87cee.json',
#   'created_at': '2023-12-27 13:58:21 UTC',
#   'processed_at': '2023-12-27 13:58:21 UTC',
#   'google_scholar_url': 'https://scholar.google.com/scholar?q=why+do+tree-based+models+outperform+deep+learning%3F&hl=en',
#   'raw_html_file': 'https://serpapi.com/searches/6daa55cb6296e7ee/658c2d7d17f923a648d87cee.html',
#   'total_time_taken': 5.27},
#  'search_parameters': {'engine': 'google_scholar',
#   'q': 'why do tree-based models outperform deep learning?',
#   'hl': 'en'},
#  'search_information': {'organic_results_state': 'Results for exact spelling',
#   'total_results': 25200,
#   'time_taken_displayed': 0.28,
#   'query_displayed': 'why do tree-based models outperform deep learning?'},
#  'organic_results': [{'position': 0,
#    'title': 'Why do tree-based models still outperform deep learning on typical tabular data?',
#    'result_id': 'RNHQ3wWAEpUJ',
#    'link': 'https://proceedings.neurips.cc/paper_files/paper/2022/hash/0378c7692da36807bdec87ab043cdadc-Abstract-Datasets_and_Benchmarks.html',
#    'snippet': '… compare deep learning models and tree-based models on … empirically why tree-based models outperform deep learning, … This highlights desirable biases for tabular data learning, …',
#    'publication_info': {'summary': 'L Grinsztajn, E Oyallon… - Advances in Neural …, 2022 - proceedings.neurips.cc',
#     'authors': [{'name': 'E Oyallon',
#       'link': 'https://scholar.google.com/citations?user=Y8XGVkYAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=Y8XGVkYAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'Y8XGVkYAAAAJ'}]},
#    'resources': [{'title': 'neurips.cc',
#      'file_format': 'PDF',
#      'link': 'https://proceedings.neurips.cc/paper_files/paper/2022/file/0378c7692da36807bdec87ab043cdadc-Paper-Datasets_and_Benchmarks.pdf'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=RNHQ3wWAEpUJ',
#     'cited_by': {'total': 452,
#      'link': 'https://scholar.google.com/scholar?cites=10741788823950250308&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '10741788823950250308',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=10741788823950250308&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:RNHQ3wWAEpUJ:scholar.google.com/&scioq=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3ARNHQ3wWAEpUJ%3Ascholar.google.com%2F',
#     'versions': {'total': 18,
#      'link': 'https://scholar.google.com/scholar?cluster=10741788823950250308&hl=en&as_sdt=0,33',
#      'cluster_id': '10741788823950250308',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=10741788823950250308&engine=google_scholar&hl=en'},
#     'cached_page_link': 'https://scholar.googleusercontent.com/scholar?q=cache:RNHQ3wWAEpUJ:scholar.google.com/+why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33'}},
#   {'position': 1,
#    'title': 'When are tree structures necessary for deep learning of representations?',
#    'result_id': 'rQtQG6Vp33kJ',
#    'link': 'https://arxiv.org/abs/1503.00185',
#    'snippet': '… is to understand better when, and why, recursive models are needed to outperform simpler models … of long sentences thus provides a simple approximation to parse-tree based models. …',
#    'publication_info': {'summary': 'J Li, MT Luong, D Jurafsky, E Hovy - arXiv preprint arXiv:1503.00185, 2015 - arxiv.org',
#     'authors': [{'name': 'J Li',
#       'link': 'https://scholar.google.com/citations?user=PwU16JEAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=PwU16JEAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'PwU16JEAAAAJ'},
#      {'name': 'MT Luong',
#       'link': 'https://scholar.google.com/citations?user=Bmbkv6sAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=Bmbkv6sAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'Bmbkv6sAAAAJ'},
#      {'name': 'D Jurafsky',
#       'link': 'https://scholar.google.com/citations?user=uZg9l58AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=uZg9l58AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'uZg9l58AAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/1503.00185'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=rQtQG6Vp33kJ',
#     'cited_by': {'total': 258,
#      'link': 'https://scholar.google.com/scholar?cites=8781853956244507565&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '8781853956244507565',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=8781853956244507565&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:rQtQG6Vp33kJ:scholar.google.com/&scioq=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3ArQtQG6Vp33kJ%3Ascholar.google.com%2F',
#     'versions': {'total': 12,
#      'link': 'https://scholar.google.com/scholar?cluster=8781853956244507565&hl=en&as_sdt=0,33',
#      'cluster_id': '8781853956244507565',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=8781853956244507565&engine=google_scholar&hl=en'},
#     'cached_page_link': 'https://scholar.googleusercontent.com/scholar?q=cache:rQtQG6Vp33kJ:scholar.google.com/+why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33'}},
#   {'position': 2,
#    'title': 'Learning tree-based deep model for recommender systems',
#    'result_id': 'vju9KpoglkcJ',
#    'link': 'https://dl.acm.org/doi/abs/10.1145/3219819.3219826',
#    'snippet': '… models such as deep neural networks. Our main idea … , which show that TDM outperforms existing methods significantly. … to construct and learn the tree used in the tree-based model. …',
#    'publication_info': {'summary': 'H Zhu, X Li, P Zhang, G Li, J He, H Li… - Proceedings of the 24th …, 2018 - dl.acm.org',
#     'authors': [{'name': 'H Zhu',
#       'link': 'https://scholar.google.com/citations?user=kAT8BcIAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=kAT8BcIAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'kAT8BcIAAAAJ'},
#      {'name': 'X Li',
#       'link': 'https://scholar.google.com/citations?user=C7lf42cAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=C7lf42cAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'C7lf42cAAAAJ'},
#      {'name': 'P Zhang',
#       'link': 'https://scholar.google.com/citations?user=Dx68T70AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=Dx68T70AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'Dx68T70AAAAJ'},
#      {'name': 'G Li',
#       'link': 'https://scholar.google.com/citations?user=oMB6_gUAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=oMB6_gUAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'oMB6_gUAAAAJ'},
#      {'name': 'H Li',
#       'link': 'https://scholar.google.com/citations?user=IJGli9AAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=IJGli9AAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'IJGli9AAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/1801.02294'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=vju9KpoglkcJ',
#     'cited_by': {'total': 250,
#      'link': 'https://scholar.google.com/scholar?cites=5158346269713578942&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '5158346269713578942',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=5158346269713578942&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:vju9KpoglkcJ:scholar.google.com/&scioq=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3Avju9KpoglkcJ%3Ascholar.google.com%2F',
#     'versions': {'total': 3,
#      'link': 'https://scholar.google.com/scholar?cluster=5158346269713578942&hl=en&as_sdt=0,33',
#      'cluster_id': '5158346269713578942',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=5158346269713578942&engine=google_scholar&hl=en'}}},
#   {'position': 3,
#    'title': 'Tree-based machine learning methods for survey research',
#    'result_id': 'otKIbBfpEuoJ',
#    'type': 'Html',
#    'link': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7425836/',
#    'snippet': '… indicate that tree-based methods outperform logistic … information can (and should) be introduced in the model building, … by combining wave-specific tree-based models into a higher-…',
#    'publication_info': {'summary': 'C Kern, T Klausch, F Kreuter - Survey research methods, 2019 - ncbi.nlm.nih.gov',
#     'authors': [{'name': 'C Kern',
#       'link': 'https://scholar.google.com/citations?user=gZtw7mwAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=gZtw7mwAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'gZtw7mwAAAAJ'},
#      {'name': 'T Klausch',
#       'link': 'https://scholar.google.com/citations?user=Q6H4KNgAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=Q6H4KNgAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'Q6H4KNgAAAAJ'},
#      {'name': 'F Kreuter',
#       'link': 'https://scholar.google.com/citations?user=iD8Vb4MAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=iD8Vb4MAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'iD8Vb4MAAAAJ'}]},
#    'resources': [{'title': 'nih.gov',
#      'file_format': 'HTML',
#      'link': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7425836/'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=otKIbBfpEuoJ',
#     'html_version': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7425836/',
#     'cited_by': {'total': 109,
#      'link': 'https://scholar.google.com/scholar?cites=16866799841270354594&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '16866799841270354594',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=16866799841270354594&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:otKIbBfpEuoJ:scholar.google.com/&scioq=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AotKIbBfpEuoJ%3Ascholar.google.com%2F',
#     'versions': {'total': 14,
#      'link': 'https://scholar.google.com/scholar?cluster=16866799841270354594&hl=en&as_sdt=0,33',
#      'cluster_id': '16866799841270354594',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=16866799841270354594&engine=google_scholar&hl=en'}}},
#   {'position': 4,
#    'title': 'Tree-based methods',
#    'result_id': '5bvlII52I60J',
#    'link': 'https://link.springer.com/content/pdf/10.1007/978-3-031-38747-0_8.pdf',
#    'snippet': '… We see that simple stumps with an interaction depth of one perform well if enough of them are included. This model outperforms the depth-two model, and both outperform a random …',
#    'publication_info': {'summary': 'G James, D Witten, T Hastie, R Tibshirani… - … to Statistical Learning …, 2023 - Springer',
#     'authors': [{'name': 'G James',
#       'link': 'https://scholar.google.com/citations?user=KUIjZqgAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=KUIjZqgAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'KUIjZqgAAAAJ'},
#      {'name': 'D Witten',
#       'link': 'https://scholar.google.com/citations?user=bHZf-c8AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=bHZf-c8AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'bHZf-c8AAAAJ'},
#      {'name': 'T Hastie',
#       'link': 'https://scholar.google.com/citations?user=tQVe-fAAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=tQVe-fAAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'tQVe-fAAAAAJ'},
#      {'name': 'R Tibshirani',
#       'link': 'https://scholar.google.com/citations?user=ZpG_cJwAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=ZpG_cJwAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'ZpG_cJwAAAAJ'}]},
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=5bvlII52I60J',
#     'cited_by': {'total': 174,
#      'link': 'https://scholar.google.com/scholar?cites=12475945745555766245&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '12475945745555766245',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=12475945745555766245&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:5bvlII52I60J:scholar.google.com/&scioq=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3A5bvlII52I60J%3Ascholar.google.com%2F',
#     'versions': {'total': 3,
#      'link': 'https://scholar.google.com/scholar?cluster=12475945745555766245&hl=en&as_sdt=0,33',
#      'cluster_id': '12475945745555766245',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=12475945745555766245&engine=google_scholar&hl=en'}}},
#   {'position': 5,
#    'title': 'An improved Stacking framework for stock index prediction by leveraging tree-based ensemble models and deep learning algorithms',
#    'result_id': 's_McDu9NPvkJ',
#    'link': 'https://www.sciencedirect.com/science/article/pii/S0378437119313093',
#    'snippet': '… improved Stacking method outperforms state-of-the-art ensemble learning algorithms and … In addition, our results indicate that these tree-based models acquire more consistent learning …',
#    'publication_info': {'summary': 'M Jiang, J Liu, L Zhang, C Liu - Physica A: Statistical Mechanics and its …, 2020 - Elsevier',
#     'authors': [{'name': 'M Jiang',
#       'link': 'https://scholar.google.com/citations?user=OBdS69UAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=OBdS69UAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'OBdS69UAAAAJ'}]},
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=s_McDu9NPvkJ',
#     'cited_by': {'total': 105,
#      'link': 'https://scholar.google.com/scholar?cites=17959878053129417651&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '17959878053129417651',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=17959878053129417651&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:s_McDu9NPvkJ:scholar.google.com/&scioq=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3As_McDu9NPvkJ%3Ascholar.google.com%2F',
#     'versions': {'total': 4,
#      'link': 'https://scholar.google.com/scholar?cluster=17959878053129417651&hl=en&as_sdt=0,33',
#      'cluster_id': '17959878053129417651',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=17959878053129417651&engine=google_scholar&hl=en'}}},
#   {'position': 6,
#    'title': 'Runtime optimizations for tree-based machine learning models',
#    'result_id': 'mCIUZ4O-i44J',
#    'link': 'https://ieeexplore.ieee.org/abstract/document/6513227/',
#    'snippet': '… Thus, for machine learning in financial engineering, models … implementations of tree-based models that are highly-tuned … if-else blocks outperform all other implementations regardless …',
#    'publication_info': {'summary': 'N Asadi, J Lin, AP De Vries - IEEE transactions on Knowledge …, 2013 - ieeexplore.ieee.org',
#     'authors': [{'name': 'J Lin',
#       'link': 'https://scholar.google.com/citations?user=0EWw1z8AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=0EWw1z8AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': '0EWw1z8AAAAJ'},
#      {'name': 'AP De Vries',
#       'link': 'https://scholar.google.com/citations?user=iH9TVHQAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=iH9TVHQAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'iH9TVHQAAAAJ'}]},
#    'resources': [{'title': 'core.ac.uk',
#      'file_format': 'PDF',
#      'link': 'https://core.ac.uk/download/pdf/208532992.pdf'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=mCIUZ4O-i44J',
#     'cited_by': {'total': 79,
#      'link': 'https://scholar.google.com/scholar?cites=10271512846727914136&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '10271512846727914136',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=10271512846727914136&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:mCIUZ4O-i44J:scholar.google.com/&scioq=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AmCIUZ4O-i44J%3Ascholar.google.com%2F',
#     'versions': {'total': 11,
#      'link': 'https://scholar.google.com/scholar?cluster=10271512846727914136&hl=en&as_sdt=0,33',
#      'cluster_id': '10271512846727914136',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=10271512846727914136&engine=google_scholar&hl=en'}}},
#   {'position': 7,
#    'title': 'Lessons learned from using a deep tree-based model for software defect prediction in practice',
#    'result_id': 'G4vQoliizV0J',
#    'link': 'https://ieeexplore.ieee.org/abstract/document/8816787/',
#    'snippet': '… deploying a new deep learning tree-based defect prediction model in practice. This model is built upon … [7] their DBN approach outperformed both the software metrics and Bag-of-Word …',
#    'publication_info': {'summary': 'HK Dam, T Pham, SW Ng, T Tran… - 2019 IEEE/ACM 16th …, 2019 - ieeexplore.ieee.org',
#     'authors': [{'name': 'HK Dam',
#       'link': 'https://scholar.google.com/citations?user=LzBiAcsAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=LzBiAcsAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'LzBiAcsAAAAJ'},
#      {'name': 'T Tran',
#       'link': 'https://scholar.google.com/citations?user=zvspVLwAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=zvspVLwAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'zvspVLwAAAAJ'}]},
#    'resources': [{'title': 'githubusercontent.com',
#      'file_format': 'PDF',
#      'link': 'https://raw.githubusercontent.com/nzjohng/publications/master/papers/msr2019.pdf'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=G4vQoliizV0J',
#     'cited_by': {'total': 90,
#      'link': 'https://scholar.google.com/scholar?cites=6759237117325380379&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '6759237117325380379',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=6759237117325380379&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:G4vQoliizV0J:scholar.google.com/&scioq=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AG4vQoliizV0J%3Ascholar.google.com%2F',
#     'versions': {'total': 9,
#      'link': 'https://scholar.google.com/scholar?cluster=6759237117325380379&hl=en&as_sdt=0,33',
#      'cluster_id': '6759237117325380379',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=6759237117325380379&engine=google_scholar&hl=en'}}},
#   {'position': 8,
#    'title': 'Tree-based machine learning methods for modeling and forecasting mortality',
#    'result_id': 'HQz0HJFN91QJ',
#    'link': 'https://www.cambridge.org/core/journals/astin-bulletin-journal-of-the-iaa/article/treebased-machine-learning-methods-for-modeling-and-forecasting-mortality/E3C440BB50665857FFEE3F4555BBEA18',
#    'snippet': '… pure, tree-based models significantly outperform all … machine learning models, we demonstrate how to extract information about the relationships uncovered by the tree-based models. …',
#    'publication_info': {'summary': 'DS Bjerre - ASTIN Bulletin: The Journal of the IAA, 2022 - cambridge.org',
#     'authors': [{'name': 'DS Bjerre',
#       'link': 'https://scholar.google.com/citations?user=PDJB0t4AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=PDJB0t4AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'PDJB0t4AAAAJ'}]},
#    'resources': [{'title': 'au.dk',
#      'file_format': 'PDF',
#      'link': 'https://pure.au.dk/portal/files/334244687/PhD_dissertation_DoretheSkovgaardBjerre.pdf#page=87'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=HQz0HJFN91QJ',
#     'cited_by': {'total': 5,
#      'link': 'https://scholar.google.com/scholar?cites=6122447504084831261&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '6122447504084831261',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=6122447504084831261&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:HQz0HJFN91QJ:scholar.google.com/&scioq=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AHQz0HJFN91QJ%3Ascholar.google.com%2F',
#     'versions': {'total': 3,
#      'link': 'https://scholar.google.com/scholar?cluster=6122447504084831261&hl=en&as_sdt=0,33',
#      'cluster_id': '6122447504084831261',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=6122447504084831261&engine=google_scholar&hl=en'}}},
#   {'position': 9,
#    'title': 'A deep tree-based model for software defect prediction',
#    'result_id': 'fTFhwGqDHRgJ',
#    'link': 'https://arxiv.org/abs/1802.00921',
#    'snippet': '… prediction model which is capable of automatically learning … Our prediction system is built upon the powerful deep learning… model which has been evaluated to perform better than using …',
#    'publication_info': {'summary': 'HK Dam, T Pham, SW Ng, T Tran, J Grundy… - arXiv preprint arXiv …, 2018 - arxiv.org',
#     'authors': [{'name': 'HK Dam',
#       'link': 'https://scholar.google.com/citations?user=LzBiAcsAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=LzBiAcsAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'LzBiAcsAAAAJ'},
#      {'name': 'T Pham',
#       'link': 'https://scholar.google.com/citations?user=JuFjX_gAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=JuFjX_gAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'JuFjX_gAAAAJ'},
#      {'name': 'T Tran',
#       'link': 'https://scholar.google.com/citations?user=zvspVLwAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=zvspVLwAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'zvspVLwAAAAJ'},
#      {'name': 'J Grundy',
#       'link': 'https://scholar.google.com/citations?user=bbEQGY8AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=bbEQGY8AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'bbEQGY8AAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/1802.00921.pdf?source=post'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=fTFhwGqDHRgJ',
#     'cited_by': {'total': 134,
#      'link': 'https://scholar.google.com/scholar?cites=1737689525752246653&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '1737689525752246653',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=1737689525752246653&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:fTFhwGqDHRgJ:scholar.google.com/&scioq=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AfTFhwGqDHRgJ%3Ascholar.google.com%2F',
#     'versions': {'total': 3,
#      'link': 'https://scholar.google.com/scholar?cluster=1737689525752246653&hl=en&as_sdt=0,33',
#      'cluster_id': '1737689525752246653',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=1737689525752246653&engine=google_scholar&hl=en'},
#     'cached_page_link': 'https://scholar.googleusercontent.com/scholar?q=cache:fTFhwGqDHRgJ:scholar.google.com/+why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33'}}],
#  'pagination': {'current': 1,
#   'next': 'https://scholar.google.com/scholar?start=10&q=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#   'other_pages': {'2': 'https://scholar.google.com/scholar?start=10&q=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#    '3': 'https://scholar.google.com/scholar?start=20&q=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#    '4': 'https://scholar.google.com/scholar?start=30&q=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#    '5': 'https://scholar.google.com/scholar?start=40&q=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#    '6': 'https://scholar.google.com/scholar?start=50&q=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#    '7': 'https://scholar.google.com/scholar?start=60&q=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#    '8': 'https://scholar.google.com/scholar?start=70&q=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#    '9': 'https://scholar.google.com/scholar?start=80&q=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33',
#    '10': 'https://scholar.google.com/scholar?start=90&q=why+do+tree-based+models+outperform+deep+learning%3F&hl=en&as_sdt=0,33'}},
#  'serpapi_pagination': {'current': 1,
#   'next_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=why+do+tree-based+models+outperform+deep+learning%3F&start=10',
#   'next': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=why+do+tree-based+models+outperform+deep+learning%3F&start=10',
#   'other_pages': {'2': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=why+do+tree-based+models+outperform+deep+learning%3F&start=10',
#    '3': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=why+do+tree-based+models+outperform+deep+learning%3F&start=20',
#    '4': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=why+do+tree-based+models+outperform+deep+learning%3F&start=30',
#    '5': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=why+do+tree-based+models+outperform+deep+learning%3F&start=40',
#    '6': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=why+do+tree-based+models+outperform+deep+learning%3F&start=50',
#    '7': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=why+do+tree-based+models+outperform+deep+learning%3F&start=60',
#    '8': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=why+do+tree-based+models+outperform+deep+learning%3F&start=70',
#    '9': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=why+do+tree-based+models+outperform+deep+learning%3F&start=80',
#    '10': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=why+do+tree-based+models+outperform+deep+learning%3F&start=90'}}}

# %%
def get_google_scholar_results(query):
    query = title
    params = {
        "engine": "google_scholar",
        "q": query,
        "api_key": GOOGLE_SEARCH_API_KEY
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    summary = results["organic_results"][0]["publication_info"]["summary"]
    publish_year = re.search(r'(19|20)\d(2)', summary).group(0)
    cited_times = results["organic_results"][0]["inline_links"]["cited_by"]["total"]

    return publish_year, cited_times
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 13
#      11 results = search.get_dict()
#      12 summary = results["organic_results"][0]["publication_info"]["summary"]
# ---> 13 publish_year = re.search(r'(19|20)\d(2)', summary).group(0)
#      14 cited_times = results["organic_results"][0]["inline_links"]["cited_by"]["total"]
#      16 # return publish_year, cited_times
#
# AttributeError: 'NoneType' object has no attribute 'group'

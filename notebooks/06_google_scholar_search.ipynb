# %%
import os
from serpapi import GoogleSearch
import regex as re

# %%
GOOGLE_SEARCH_API_KEY = os.environ["GOOGLE_SEARCH_API_KEY"]

# %%
title = "SummEval: Re-evaluating Summarization Evaluation"
params = {
    "engine": "google_scholar",
    "q": title,
    "api_key": GOOGLE_SEARCH_API_KEY
}

search = GoogleSearch(params)
results = search.get_dict()

# %%
results
# Out:
# {'search_metadata': {'id': '659f072dcace96cd7eaec121',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/5e8dbb073f09bca5/659f072dcace96cd7eaec121.json',
#   'created_at': '2024-01-10 21:07:57 UTC',
#   'processed_at': '2024-01-10 21:07:57 UTC',
#   'google_scholar_url': 'https://scholar.google.com/scholar?q=SummEval%3A+Re-evaluating+Summarization+Evaluation&hl=en',
#   'raw_html_file': 'https://serpapi.com/searches/5e8dbb073f09bca5/659f072dcace96cd7eaec121.html',
#   'total_time_taken': 1.66},
#  'search_parameters': {'engine': 'google_scholar',
#   'q': 'SummEval: Re-evaluating Summarization Evaluation',
#   'hl': 'en'},
#  'search_information': {'organic_results_state': 'Results for exact spelling',
#   'total_results': 455,
#   'time_taken_displayed': 0.07,
#   'query_displayed': 'SummEval: Re-evaluating Summarization Evaluation'},
#  'organic_results': [{'position': 0,
#    'title': 'Summeval: Re-evaluating summarization evaluation',
#    'result_id': 'Ac29DmTSKJgJ',
#    'link': 'https://direct.mit.edu/tacl/article-abstract/doi/10.1162/tacl_a_00373/100686',
#    'snippet': '… and the lack of consensus regarding evaluation protocols continue to inhibit … of summarization evaluation methods along five dimensions: 1) we re-evaluate 14 automatic evaluation …',
#    'publication_info': {'summary': 'AR Fabbri, W Kryściński, B McCann, C Xiong… - Transactions of the …, 2021 - direct.mit.edu',
#     'authors': [{'name': 'AR Fabbri',
#       'link': 'https://scholar.google.com/citations?user=DknNWHkAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=DknNWHkAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'DknNWHkAAAAJ'},
#      {'name': 'W Kryściński',
#       'link': 'https://scholar.google.com/citations?user=m3kSadoAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=m3kSadoAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'm3kSadoAAAAJ'},
#      {'name': 'B McCann',
#       'link': 'https://scholar.google.com/citations?user=QVj22CwAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=QVj22CwAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'QVj22CwAAAAJ'},
#      {'name': 'C Xiong',
#       'link': 'https://scholar.google.com/citations?user=vaSdahkAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=vaSdahkAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'vaSdahkAAAAJ'}]},
#    'resources': [{'title': 'mit.edu',
#      'file_format': 'HTML',
#      'link': 'https://direct.mit.edu/tacl/article/doi/10.1162/tacl_a_00373/100686'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=Ac29DmTSKJgJ',
#     'html_version': 'https://direct.mit.edu/tacl/article/doi/10.1162/tacl_a_00373/100686',
#     'cited_by': {'total': 419,
#      'link': 'https://scholar.google.com/scholar?cites=10964244620019354881&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '10964244620019354881',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=10964244620019354881&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:Ac29DmTSKJgJ:scholar.google.com/&scioq=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AAc29DmTSKJgJ%3Ascholar.google.com%2F',
#     'versions': {'total': 7,
#      'link': 'https://scholar.google.com/scholar?cluster=10964244620019354881&hl=en&as_sdt=0,33',
#      'cluster_id': '10964244620019354881',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=10964244620019354881&engine=google_scholar&hl=en'}}},
#   {'position': 1,
#    'title': 'SummEval: Re-evaluating Summarization Evaluation',
#    'result_id': 'S6Tryq6PwlYJ',
#    'type': 'Pdf',
#    'link': 'https://www.academia.edu/download/78997139/tacl_a_00373.pdf',
#    'snippet': '… metrics for text summarization and the lack of consensus regarding evaluation … of summarization evaluation methods along five dimensions: 1) we re-evaluate 14 automatic evaluation …',
#    'publication_info': {'summary': 'B McCann, C Xiong, R Socher, D Radev - academia.edu',
#     'authors': [{'name': 'B McCann',
#       'link': 'https://scholar.google.com/citations?user=QVj22CwAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=QVj22CwAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'QVj22CwAAAAJ'},
#      {'name': 'C Xiong',
#       'link': 'https://scholar.google.com/citations?user=vaSdahkAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=vaSdahkAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'vaSdahkAAAAJ'},
#      {'name': 'R Socher',
#       'link': 'https://scholar.google.com/citations?user=FaOcyfMAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=FaOcyfMAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'FaOcyfMAAAAJ'},
#      {'name': 'D Radev',
#       'link': 'https://scholar.google.com/citations?user=vIqWvgwAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=vIqWvgwAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'vIqWvgwAAAAJ'}]},
#    'resources': [{'title': 'academia.edu',
#      'file_format': 'PDF',
#      'link': 'https://www.academia.edu/download/78997139/tacl_a_00373.pdf'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=S6Tryq6PwlYJ',
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:S6Tryq6PwlYJ:scholar.google.com/&scioq=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AS6Tryq6PwlYJ%3Ascholar.google.com%2F',
#     'cached_page_link': 'https://scholar.googleusercontent.com/scholar?q=cache:S6Tryq6PwlYJ:scholar.google.com/+SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33'}},
#   {'position': 2,
#    'title': 'DialSummEval: Revisiting summarization evaluation for dialogues',
#    'result_id': 'X5-C3KA19ngJ',
#    'link': 'https://aclanthology.org/2022.naacl-main.418/',
#    'snippet': '… 3) We re-evaluate the performance of 18 types of automatic evaluation metrics on dialogue summarization. 4) We evaluate a variety of dialogue summarization models (extractive, …',
#    'publication_info': {'summary': 'M Gao, X Wan - Proceedings of the 2022 Conference of the North …, 2022 - aclanthology.org',
#     'authors': [{'name': 'M Gao',
#       'link': 'https://scholar.google.com/citations?user=irw09VcAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=irw09VcAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'irw09VcAAAAJ'},
#      {'name': 'X Wan',
#       'link': 'https://scholar.google.com/citations?user=lTTeBdkAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=lTTeBdkAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'lTTeBdkAAAAJ'}]},
#    'resources': [{'title': 'aclanthology.org',
#      'file_format': 'PDF',
#      'link': 'https://aclanthology.org/2022.naacl-main.418.pdf'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=X5-C3KA19ngJ',
#     'cited_by': {'total': 13,
#      'link': 'https://scholar.google.com/scholar?cites=8716213093832761183&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '8716213093832761183',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=8716213093832761183&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:X5-C3KA19ngJ:scholar.google.com/&scioq=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AX5-C3KA19ngJ%3Ascholar.google.com%2F',
#     'versions': {'total': 6,
#      'link': 'https://scholar.google.com/scholar?cluster=8716213093832761183&hl=en&as_sdt=0,33',
#      'cluster_id': '8716213093832761183',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=8716213093832761183&engine=google_scholar&hl=en'},
#     'cached_page_link': 'https://scholar.googleusercontent.com/scholar?q=cache:X5-C3KA19ngJ:scholar.google.com/+SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33'}},
#   {'position': 3,
#    'title': 'Questeval: Summarization asks for fact-based evaluation',
#    'result_id': 'mUP-YGuOwZQJ',
#    'link': 'https://arxiv.org/abs/2103.12693',
#    'snippet': '… In Table 3, we measure how the percentage of questions belonging to a specific fold correlates with the Relevance dimension for each generated summary on SummEval. We observe …',
#    'publication_info': {'summary': 'T Scialom, PA Dray, P Gallinari, S Lamprier… - arXiv preprint arXiv …, 2021 - arxiv.org',
#     'authors': [{'name': 'T Scialom',
#       'link': 'https://scholar.google.com/citations?user=qou4P-kAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=qou4P-kAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'qou4P-kAAAAJ'},
#      {'name': 'PA Dray',
#       'link': 'https://scholar.google.com/citations?user=OH0S3p8AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=OH0S3p8AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'OH0S3p8AAAAJ'},
#      {'name': 'P Gallinari',
#       'link': 'https://scholar.google.com/citations?user=rFaxB20AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=rFaxB20AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'rFaxB20AAAAJ'},
#      {'name': 'S Lamprier',
#       'link': 'https://scholar.google.com/citations?user=NuGN8SUAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=NuGN8SUAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'NuGN8SUAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/2103.12693'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=mUP-YGuOwZQJ',
#     'cited_by': {'total': 149,
#      'link': 'https://scholar.google.com/scholar?cites=10719005179958412185&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '10719005179958412185',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=10719005179958412185&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:mUP-YGuOwZQJ:scholar.google.com/&scioq=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AmUP-YGuOwZQJ%3Ascholar.google.com%2F',
#     'versions': {'total': 16,
#      'link': 'https://scholar.google.com/scholar?cluster=10719005179958412185&hl=en&as_sdt=0,33',
#      'cluster_id': '10719005179958412185',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=10719005179958412185&engine=google_scholar&hl=en'},
#     'cached_page_link': 'https://scholar.googleusercontent.com/scholar?q=cache:mUP-YGuOwZQJ:scholar.google.com/+SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33'}},
#   {'position': 4,
#    'title': 'From COMET to COMES–Can Summary Evaluation Benefit from Translation Evaluation?',
#    'result_id': 'WsUYGI5GVd8J',
#    'type': 'Pdf',
#    'link': 'https://aclanthology.org/2022.eval4nlp-1.3.pdf',
#    'snippet': '… un-biased reporting on the whole SummEval dataset and thus is a … Summarization is the length of the typical input. By examining the lengths of the tokenized documents from SummEval…',
#    'publication_info': {'summary': 'M Krubiński, P Pecina - … of the 3rd Workshop on Evaluation and …, 2022 - aclanthology.org',
#     'authors': [{'name': 'M Krubiński',
#       'link': 'https://scholar.google.com/citations?user=12NoTUUAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=12NoTUUAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': '12NoTUUAAAAJ'},
#      {'name': 'P Pecina',
#       'link': 'https://scholar.google.com/citations?user=NMFKnr8AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=NMFKnr8AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'NMFKnr8AAAAJ'}]},
#    'resources': [{'title': 'aclanthology.org',
#      'file_format': 'PDF',
#      'link': 'https://aclanthology.org/2022.eval4nlp-1.3.pdf'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=WsUYGI5GVd8J',
#     'cited_by': {'total': 2,
#      'link': 'https://scholar.google.com/scholar?cites=16092846419581912410&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '16092846419581912410',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=16092846419581912410&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:WsUYGI5GVd8J:scholar.google.com/&scioq=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AWsUYGI5GVd8J%3Ascholar.google.com%2F',
#     'versions': {'total': 3,
#      'link': 'https://scholar.google.com/scholar?cluster=16092846419581912410&hl=en&as_sdt=0,33',
#      'cluster_id': '16092846419581912410',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=16092846419581912410&engine=google_scholar&hl=en'},
#     'cached_page_link': 'https://scholar.googleusercontent.com/scholar?q=cache:WsUYGI5GVd8J:scholar.google.com/+SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33'}},
#   {'position': 5,
#    'title': 'A statistical analysis of summarization evaluation metrics using resampling methods',
#    'result_id': '_iXRFlqYbN4J',
#    'link': 'https://direct.mit.edu/tacl/article-abstract/doi/10.1162/tacl_a_00417/107833',
#    'snippet': '… Although we focus on summarization, the techniques we propose can be applied to evaluate automatic evaluation metrics in other … SummEval: Re-evaluating summarization evaluation …',
#    'publication_info': {'summary': 'D Deutsch, R Dror, D Roth - Transactions of the Association for …, 2021 - direct.mit.edu',
#     'authors': [{'name': 'D Deutsch',
#       'link': 'https://scholar.google.com/citations?user=TQYzWDEAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=TQYzWDEAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'TQYzWDEAAAAJ'},
#      {'name': 'R Dror',
#       'link': 'https://scholar.google.com/citations?user=ZB0tZNEAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=ZB0tZNEAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'ZB0tZNEAAAAJ'},
#      {'name': 'D Roth',
#       'link': 'https://scholar.google.com/citations?user=E-bpPWgAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=E-bpPWgAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'E-bpPWgAAAAJ'}]},
#    'resources': [{'title': 'mit.edu',
#      'file_format': 'HTML',
#      'link': 'https://direct.mit.edu/tacl/article/doi/10.1162/tacl_a_00417/107833'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=_iXRFlqYbN4J',
#     'html_version': 'https://direct.mit.edu/tacl/article/doi/10.1162/tacl_a_00417/107833',
#     'cited_by': {'total': 42,
#      'link': 'https://scholar.google.com/scholar?cites=16027352686602036734&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '16027352686602036734',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=16027352686602036734&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:_iXRFlqYbN4J:scholar.google.com/&scioq=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3A_iXRFlqYbN4J%3Ascholar.google.com%2F',
#     'versions': {'total': 9,
#      'link': 'https://scholar.google.com/scholar?cluster=16027352686602036734&hl=en&as_sdt=0,33',
#      'cluster_id': '16027352686602036734',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=16027352686602036734&engine=google_scholar&hl=en'}}},
#   {'position': 6,
#    'title': 'Factual consistency evaluation for text summarization via counterfactual estimation',
#    'result_id': 'aM_TmUFxcV0J',
#    'link': 'https://arxiv.org/abs/2108.13134',
#    'snippet': '… Y , ie, Pr(yt), as one of the factual consistency scores for the evaluated summary if yt is a key … conducted on QAGS-CNN/DM and SUMMEVAL, and finetuned on the training set of XSUM …',
#    'publication_info': {'summary': 'Y Xie, F Sun, Y Deng, Y Li, B Ding - arXiv preprint arXiv:2108.13134, 2021 - arxiv.org',
#     'authors': [{'name': 'Y Xie',
#       'link': 'https://scholar.google.com/citations?user=fhWk0gEAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=fhWk0gEAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'fhWk0gEAAAAJ'},
#      {'name': 'F Sun',
#       'link': 'https://scholar.google.com/citations?user=OlRxBhcAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=OlRxBhcAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'OlRxBhcAAAAJ'},
#      {'name': 'Y Deng',
#       'link': 'https://scholar.google.com/citations?user=OshWT3UAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=OshWT3UAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'OshWT3UAAAAJ'},
#      {'name': 'Y Li',
#       'link': 'https://scholar.google.com/citations?user=CCPBcdYAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=CCPBcdYAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'CCPBcdYAAAAJ'},
#      {'name': 'B Ding',
#       'link': 'https://scholar.google.com/citations?user=AjYkTi8AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=AjYkTi8AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'AjYkTi8AAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/2108.13134'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=aM_TmUFxcV0J',
#     'cited_by': {'total': 39,
#      'link': 'https://scholar.google.com/scholar?cites=6733287444463210344&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '6733287444463210344',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=6733287444463210344&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:aM_TmUFxcV0J:scholar.google.com/&scioq=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AaM_TmUFxcV0J%3Ascholar.google.com%2F',
#     'versions': {'total': 7,
#      'link': 'https://scholar.google.com/scholar?cluster=6733287444463210344&hl=en&as_sdt=0,33',
#      'cluster_id': '6733287444463210344',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=6733287444463210344&engine=google_scholar&hl=en'},
#     'cached_page_link': 'https://scholar.googleusercontent.com/scholar?q=cache:aM_TmUFxcV0J:scholar.google.com/+SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33'}},
#   {'position': 7,
#    'title': 'QAFactEval: Improved QA-based factual consistency evaluation for summarization',
#    'result_id': 'WH3654TUuBoJ',
#    'link': 'https://arxiv.org/abs/2112.08542',
#    'snippet': '… Thus, determining the factual consistency of a summary remains an essential task. Recent metrics for summarization factual consistency can be broadly split into two categories: 1) …',
#    'publication_info': {'summary': 'AR Fabbri, CS Wu, W Liu, C Xiong - arXiv preprint arXiv:2112.08542, 2021 - arxiv.org',
#     'authors': [{'name': 'AR Fabbri',
#       'link': 'https://scholar.google.com/citations?user=DknNWHkAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=DknNWHkAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'DknNWHkAAAAJ'},
#      {'name': 'CS Wu',
#       'link': 'https://scholar.google.com/citations?user=1G4GV2EAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=1G4GV2EAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': '1G4GV2EAAAAJ'},
#      {'name': 'W Liu',
#       'link': 'https://scholar.google.com/citations?user=BaRpQ_kAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=BaRpQ_kAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'BaRpQ_kAAAAJ'},
#      {'name': 'C Xiong',
#       'link': 'https://scholar.google.com/citations?user=vaSdahkAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=vaSdahkAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'vaSdahkAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/2112.08542'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=WH3654TUuBoJ',
#     'cited_by': {'total': 77,
#      'link': 'https://scholar.google.com/scholar?cites=1925522507993611608&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '1925522507993611608',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=1925522507993611608&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:WH3654TUuBoJ:scholar.google.com/&scioq=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AWH3654TUuBoJ%3Ascholar.google.com%2F',
#     'versions': {'total': 3,
#      'link': 'https://scholar.google.com/scholar?cluster=1925522507993611608&hl=en&as_sdt=0,33',
#      'cluster_id': '1925522507993611608',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=1925522507993611608&engine=google_scholar&hl=en'},
#     'cached_page_link': 'https://scholar.googleusercontent.com/scholar?q=cache:WH3654TUuBoJ:scholar.google.com/+SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33'}},
#   {'position': 8,
#    'title': 'Re-examining system-level correlations of automatic summarization evaluation metrics',
#    'result_id': 'yM5G5T1Tt50J',
#    'link': 'https://arxiv.org/abs/2204.10216',
#    'snippet': '… We find that the widths of the CIs shrank on average by 51% on SummEval and 16% on REALSumm. The largest decrease in width is in the ROUGE family of metrics on SummEval, …',
#    'publication_info': {'summary': 'D Deutsch, R Dror, D Roth - arXiv preprint arXiv:2204.10216, 2022 - arxiv.org',
#     'authors': [{'name': 'D Deutsch',
#       'link': 'https://scholar.google.com/citations?user=TQYzWDEAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=TQYzWDEAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'TQYzWDEAAAAJ'},
#      {'name': 'R Dror',
#       'link': 'https://scholar.google.com/citations?user=ZB0tZNEAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=ZB0tZNEAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'ZB0tZNEAAAAJ'},
#      {'name': 'D Roth',
#       'link': 'https://scholar.google.com/citations?user=E-bpPWgAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=E-bpPWgAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'E-bpPWgAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/2204.10216'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=yM5G5T1Tt50J',
#     'cited_by': {'total': 20,
#      'link': 'https://scholar.google.com/scholar?cites=11364643709997469384&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '11364643709997469384',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=11364643709997469384&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:yM5G5T1Tt50J:scholar.google.com/&scioq=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AyM5G5T1Tt50J%3Ascholar.google.com%2F',
#     'versions': {'total': 4,
#      'link': 'https://scholar.google.com/scholar?cluster=11364643709997469384&hl=en&as_sdt=0,33',
#      'cluster_id': '11364643709997469384',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=11364643709997469384&engine=google_scholar&hl=en'},
#     'cached_page_link': 'https://scholar.googleusercontent.com/scholar?q=cache:yM5G5T1Tt50J:scholar.google.com/+SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33'}},
#   {'position': 9,
#    'title': 'Maskeval: Weighted mlm-based evaluation for text summarization and simplification',
#    'result_id': 'xyu_J64cpegJ',
#    'link': 'https://arxiv.org/abs/2205.12394',
#    'snippet': '… In Figure 5, we report the Pearson correlation on the test subset of SummEval when only some weighted MLM steps are used in the computation of the MaskEval score (ie we apply the …',
#    'publication_info': {'summary': 'YL Liu, R Bawden, T Scialom, B Sagot… - arXiv preprint arXiv …, 2022 - arxiv.org',
#     'authors': [{'name': 'R Bawden',
#       'link': 'https://scholar.google.com/citations?user=G3DS5GAAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=G3DS5GAAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'G3DS5GAAAAAJ'},
#      {'name': 'T Scialom',
#       'link': 'https://scholar.google.com/citations?user=qou4P-kAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=qou4P-kAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'qou4P-kAAAAJ'},
#      {'name': 'B Sagot',
#       'link': 'https://scholar.google.com/citations?user=HXUT9ZkAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=HXUT9ZkAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'HXUT9ZkAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/2205.12394'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&hl=en&q=xyu_J64cpegJ',
#     'cited_by': {'total': 6,
#      'link': 'https://scholar.google.com/scholar?cites=16763836722273266631&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '16763836722273266631',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=16763836722273266631&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:xyu_J64cpegJ:scholar.google.com/&scioq=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3Axyu_J64cpegJ%3Ascholar.google.com%2F',
#     'versions': {'total': 3,
#      'link': 'https://scholar.google.com/scholar?cluster=16763836722273266631&hl=en&as_sdt=0,33',
#      'cluster_id': '16763836722273266631',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=16763836722273266631&engine=google_scholar&hl=en'},
#     'cached_page_link': 'https://scholar.googleusercontent.com/scholar?q=cache:xyu_J64cpegJ:scholar.google.com/+SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33'}}],
#  'related_searches': [{'query': 'summarization evaluation metrics',
#    'link': 'https://scholar.google.com/scholar?hl=en&as_sdt=0,33&qsp=1&q=summarization+evaluation+metrics&qst=br'},
#   {'query': 'text summarization evaluation',
#    'link': 'https://scholar.google.com/scholar?hl=en&as_sdt=0,33&qsp=2&q=text+summarization+evaluation&qst=br'},
#   {'query': 'summarization evaluation selection variation',
#    'link': 'https://scholar.google.com/scholar?hl=en&as_sdt=0,33&qsp=3&q=summarization+evaluation+selection+variation&qst=br'},
#   {'query': 'summary evaluation balanced degree',
#    'link': 'https://scholar.google.com/scholar?hl=en&as_sdt=0,33&qsp=4&q=summary+evaluation+balanced+degree&qst=br'},
#   {'query': 'summarization evaluation word embeddings',
#    'link': 'https://scholar.google.com/scholar?hl=en&as_sdt=0,33&qsp=5&q=summarization+evaluation+word+embeddings&qst=br'},
#   {'query': 'summary evaluation other languages',
#    'link': 'https://scholar.google.com/scholar?hl=en&as_sdt=0,33&qsp=6&q=summary+evaluation+other+languages&qst=br'},
#   {'query': 'summarization evaluation gold standard',
#    'link': 'https://scholar.google.com/scholar?hl=en&as_sdt=0,33&qsp=7&q=summarization+evaluation+gold+standard&qst=br'},
#   {'query': 'document summarization evaluation challenges',
#    'link': 'https://scholar.google.com/scholar?hl=en&as_sdt=0,33&qsp=8&q=document+summarization+evaluation+challenges&qst=br'},
#   {'query': 'multilingual summarization factual consistency evaluation',
#    'link': 'https://scholar.google.com/scholar?hl=en&as_sdt=0,33&qsp=9&q=multilingual+summarization+factual+consistency+evaluation&qst=br'},
#   {'query': 'summarization methods survey on evaluation',
#    'link': 'https://scholar.google.com/scholar?hl=en&as_sdt=0,33&qsp=10&q=summarization+methods+survey+on+evaluation&qst=br'},
#   {'query': 'multi-document summarization unsupervised evaluation metrics',
#    'link': 'https://scholar.google.com/scholar?hl=en&as_sdt=0,33&qsp=11&q=multi-document+summarization+unsupervised+evaluation+metrics&qst=br'},
#   {'query': 'multi-document summarization automatic evaluation',
#    'link': 'https://scholar.google.com/scholar?hl=en&as_sdt=0,33&qsp=12&q=multi-document+summarization+automatic+evaluation&qst=br'},
#   {'query': 'summarization evaluation pyramid method',
#    'link': 'https://scholar.google.com/scholar?hl=en&as_sdt=0,33&qsp=13&q=summarization+evaluation+pyramid+method&qst=br'},
#   {'query': 'text summarization factual consistency evaluation',
#    'link': 'https://scholar.google.com/scholar?hl=en&as_sdt=0,33&qsp=14&q=text+summarization+factual+consistency+evaluation&qst=br'}],
#  'pagination': {'current': 1,
#   'next': 'https://scholar.google.com/scholar?start=10&q=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#   'other_pages': {'2': 'https://scholar.google.com/scholar?start=10&q=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#    '3': 'https://scholar.google.com/scholar?start=20&q=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#    '4': 'https://scholar.google.com/scholar?start=30&q=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#    '5': 'https://scholar.google.com/scholar?start=40&q=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#    '6': 'https://scholar.google.com/scholar?start=50&q=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#    '7': 'https://scholar.google.com/scholar?start=60&q=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#    '8': 'https://scholar.google.com/scholar?start=70&q=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#    '9': 'https://scholar.google.com/scholar?start=80&q=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33',
#    '10': 'https://scholar.google.com/scholar?start=90&q=SummEval:+Re-evaluating+Summarization+Evaluation&hl=en&as_sdt=0,33'}},
#  'serpapi_pagination': {'current': 1,
#   'next_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=SummEval%3A+Re-evaluating+Summarization+Evaluation&start=10',
#   'next': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=SummEval%3A+Re-evaluating+Summarization+Evaluation&start=10',
#   'other_pages': {'2': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=SummEval%3A+Re-evaluating+Summarization+Evaluation&start=10',
#    '3': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=SummEval%3A+Re-evaluating+Summarization+Evaluation&start=20',
#    '4': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=SummEval%3A+Re-evaluating+Summarization+Evaluation&start=30',
#    '5': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=SummEval%3A+Re-evaluating+Summarization+Evaluation&start=40',
#    '6': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=SummEval%3A+Re-evaluating+Summarization+Evaluation&start=50',
#    '7': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=SummEval%3A+Re-evaluating+Summarization+Evaluation&start=60',
#    '8': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=SummEval%3A+Re-evaluating+Summarization+Evaluation&start=70',
#    '9': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=SummEval%3A+Re-evaluating+Summarization+Evaluation&start=80',
#    '10': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=SummEval%3A+Re-evaluating+Summarization+Evaluation&start=90'}}}

# %%
def get_google_scholar_results(query):
    query = title
    params = {
        "engine": "google_scholar",
        "q": query,
        "api_key": GOOGLE_SEARCH_API_KEY
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    summary = results["organic_results"][0]["publication_info"]["summary"]
    publish_year = re.search(r'(19|20)\d\d', summary).group(0)
    cited_times = results["organic_results"][0]["inline_links"]["cited_by"]["total"]

    return publish_year, cited_times
